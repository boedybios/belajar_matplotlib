# %% [markdown]
# ![](./images/mpl_logo.png)
#
# # Visualisasi Data yang tersimpan pada Pandas Data Frame
#
# Dalam sesi ini kita akan mempelajari cara untuk melakukan visualisasi data yang tersimpan pada Pandas Data Frame dengan Matplotlib.

# %% [markdown]
# ## Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

print(matplotlib.__version__)
print(pd.__version__)
# Out:
# 3.3.2
# 1.1.3

# %% [markdown]
# ## Sample Dataset

# %%
df = pd.DataFrame({
    'nama':['cecep','karti','bejo','tejo','asep','wati','amat'],
    'usia':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'propinsi':['jabar','jatim','jabar','jatim','jabar','jateng','jateng'],
    'n_anak':[2,0,0,3,2,1,4],
    'n_pets':[5,1,0,5,2,2,3]
})

df
# Out:
#     nama  usia gender propinsi  n_anak  n_pets
# 0  cecep    23      M    jabar       2       5
# 1  karti    78      F    jatim       0       1
# 2   bejo    22      M    jabar       0       0
# 3   tejo    19      M    jatim       3       5
# 4   asep    45      M    jabar       2       2
# 5   wati    33      F   jateng       1       2
# 6   amat    20      M   jateng       4       3

# %% [markdown]
# ## Scatter Plot

# %%
df.plot(kind='scatter', x='n_anak', y='n_pets', color='red')

plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ## Line Plot

# %%
df.plot(kind='line', x='nama', y='n_anak', color='green')

plt.title('Line Plot')
plt.show()

# %%
df.plot(kind='line', x='nama', y='n_anak', color='green')
df.plot(kind='line', x='nama', y='n_pets', color='red')

plt.title('Line Plot')
# plt.ylabel('Jumlah')
plt.show()

# %%
ax = plt.gca()

df.plot(kind='line', x='nama', y='n_anak', color='green', ax=ax)
df.plot(kind='line', x='nama', y='n_pets', color='red', ax=ax)

plt.title('Line Plot')
# plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
df.plot(kind='bar', x='nama', y='usia')

plt.title('Bar Plot')
plt.ylabel('Jumlah')
plt.show()

# %%
df.groupby('propinsi')['nama'].nunique().plot(kind='bar')

plt.show()
